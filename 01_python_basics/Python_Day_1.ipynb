# %% [markdown]
# importance of jupyter notebook(convinient)

# %% [markdown]
# ## primitive data types:
# Quotation '',"", this is a symbolic notation of strings.
# strings: 'i am new here from hyderabad', '100', ## 'data' --> string, 'True','False'
# "i am new here from hyderabad",
# '''i am new here from hyderabad''',
# """ i am new here from hyderabad """
# integers: -1, -2, 0, 1, 2...., Are immutable
# Floats: 1.0, 3.14, 100.0. 2.5
# boolean: True, False
# complex numbers: a+ib

# %%
print("hello world") # build-in functions
# Out:
# hello world

# %%
type(True)
# Out:
# bool

# %%
type(1000)
# Out:
# int

# %%
type(1+1j)
# Out:
# complex

# %%
# decimals

# %%
from decimal import Decimal

# %%
a=Decimal(10/3)
b=Decimal(3/2)

# %%
c= a + b

# %%
print(c,type(c))
# Out:
# 4.833333333333333481363069950 <class 'decimal.Decimal'>

# %%
type(a)
# Out:
# decimal.Decimal

# %%
x=100

# %%
y=100

# %%
id(x),id(y)
# Out:
# (140723327713288, 140723327713288)

# %%
hex(id(x))
# Out:
# '0x7ffcb3f5c008'

# %%
a="hello world"

# %%
b="bye"

# %%
id(a)
# Out:
# 2810231066352

# %%
id(b)
# Out:
# 2810231365840

# %%
x=1
y=x

# %%
print(id(x),id(y))
# Out:
# 140723327710120 140723327710120

# %%
x=1
y=1

# %%
y=2

# %%
print(id(x),id(y))
# Out:
# 140723327710120 140723327710152

# %%
x=10
y=10
print(id(x),id(y))
# Out:
# 140723327710408 140723327710408

# %%
y=20
print(id(x),id(y))
# Out:
# 140723327710408 140723327710728

# %%
x='helloworld'
y=x

# %%
print(id(x),id(y))
# Out:
# 2810231122992 2810231122992

# %%
y='bye....'
print(id(x),id(y))
# Out:
# 2810231122992 2810234182544

# %%
# Int is immutable

# %%
x=10
id(x)
# Out:
# 140723327710408

# %%
x=20
id(x)
# Out:
# 140723327710728

# %%
x=300
y=300

# %%
print(id(x),id(y))
# Out:
# 2810232327088 2810232326992

# %%
x=300
y=300

# %%
x == y # used for comapring the data value
# Out:
# True

# %%
x is y # identity testing, compare the data location
# Out:
# False

# %%
x=256 # immutable
y=256
print(id(x),id(y)) # Interning --> performace optimisation
# Out:
# 140723327718280 140723327718280

# %%
x=257
y=257
print(id(x),id(y))
# Out:
# 2810232153936 2810232158960

# %%
x=-5
y=-5
print(id(x),id(y))
# Out:
# 140723327709928 140723327709928

# %%
x=-6
y=-6
print(id(x),id(y))
# Out:
# 2810232159344 2810232152944

# %%
# interning will happen for integers only within the limit 
## of [-5, 256]

# %%
myvar="helloworld" # Immutable
newvar="helloworld"

# %%
print(id(myvar),id(newvar))
# Out:
# 2810230742000 2810230742000

# %%
myvar="helloworld" # Immutable
newvar="helloworld"

# %%
print(id(myvar),id(newvar))
# Out:
# 2810230873968 2810230873968

# %%
myvar="hello world" # Immutable
newvar="hello world"
print(id(myvar),id(newvar))
# Out:
# 2810230871408 2810230866288

# %%
myvar="hello_world" # Immutable, since both data's of variables are follwoing the naming convention of variables
newvar="hello_world"   # hence they are getting interned(they will reference the same object)
print(id(myvar),id(newvar))
# Out:
# 2810230779888 2810230779888

# %%
my_var=100

# %%
message1="hello myself fasi from hyderabad i am working"
message2="hello myself fasi from hyderabad i am working"

# %%
print(id(message1), id(message2))
# Out:
# 2810223796624 2810223797104

# %%
message1="hello_myself_fasi_from_hyderabad_i_am_working"
message2="hello_myself_fasi_from_hyderabad_i_am_working"

# %%
print(id(message1), id(message2))
# Out:
# 2810232404752 2810232404752

# %%
from sys import intern

# %%
message1="hello myself fasi from hyderabad i am working"
message2="hello myself fasi from hyderabad i am working"
message1 is message2
# Out:
# False

# %%
message1=intern("hello myself fasi from hyderabad i am working")
message2=intern("hello myself fasi from hyderabad i am working")
message1 is message2 # sharing the reference: Interning
# Out:
# True
